# %%
from twisted.enterprise import adbapi   
import time  
from httplib2 import Http
from simplejson import loads, dumps
#import base64
import bson
import urllib
import urllib2
import urlparse
import csv
import json
import csv
#import MySQLdb

# %%
def get_oauth_token():
    http_obj = Http()
    url = "https://api.idealista.com/oauth/token"
    apikey= urlparse.urlparse('kn5fkovg91u9cuzo68pdiiwylgw878o1')
    secret= urlparse.urlparse('AK8NlpBSDmoV')
    auth ='ZmN2OWgybXAxcmRsZnJiZWl1aDV1bXo1b2Vya2pwaXk6YjU1T0pVVTF1UUQz' #'a241Zmtvdmc5MXU5Y3V6bzY4cGRpaXd5bGd3ODc4bzE6QUs4TmxwQlNEbW9W'#apikey + ':' + secret
    body = {'grant_type':'client_credentials'}
    headers = {'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8','Authorization' : 'Basic ' + auth}
    resp, content = http_obj.request(url,method='POST',headers=headers, body=urllib.urlencode(body))
    return json.loads(content.decode('utf-8'))["access_token"]

# %%
def save_check(dic, key):
    if key not in dic:
        return "NaN"
    return dic[key].decode("utf-8")

# %%
def search_api(token, page):
    http_obj = Http()
    #token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE0NzY5MDY1NTAsInNjb3BlIjpbInJlYWQiXSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMGM0NTc5ZDQtZWFmMi00ZTAxLWJmNGYtNTQzZDBhMWMzZGVmIiwiY2xpZW50X2lkIjoia241Zmtvdmc5MXU5Y3V6bzY4cGRpaXd5bGd3ODc4bzEifQ.SduicVE561Y23O9_IicHqZ2SrxpBiIPbMl8HMdyQcE4"
    url = "http://api.idealista.com/3.5/es/search?center=41.402165058,2.171332648&country=es&maxItems=5000&distance=40000&propertyType=homes&operation=rent&numPage=" + str(page)
    headers = {'Authorization' : 'Bearer ' + token}
    resp, content = http_obj.request(url,method='POST',headers=headers)
    return json.loads(content.decode('utf-8'))

# %%
resp
# Out:
# {'cache-control': 'max-age=0',
#  'content-type': 'application/json;charset=UTF-8',
#  'date': 'Mon, 14 Nov 2016 19:19:31 GMT',
#  'expires': 'Mon, 14 Nov 2016 19:19:31 GMT',
#  'server': 'idealista',
#  'set-cookie': 'APIPUBID=A|WCoOV|WCoOV; path=/; HttpOnly',
#  'status': '200',
#  'transfer-encoding': 'chunked'}

# %%
content
# Out:
# '{"elementList":[{"propertyCode":"35148292","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRBIt304N1zbEaVTYiMKa7peJb6h3pOitYjII8tYJyqXAenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=871973808","externalReference":"gava 650","numPhotos":6,"floor":"4","price":650.0,"propertyType":"flat","operation":"rent","size":66.0,"exterior":true,"rooms":3,"bathrooms":1,"address":"avenida de l\'Erampruny\xc3\xa0","province":"Barcelona","municipality":"Gav\xc3\xa0","district":"Centre - Colomeres - Ramblas","country":"es","latitude":41.3086987,"longitude":1.9935823,"showAddress":false,"url":"http://www.idealista.com/35148292","distance":"18113","hasVideo":false,"status":"good","newDevelopment":false,"hasLift":true,"priceByArea":10.0,"detailedType":{"typology":"flat"},"suggestedTexts":{"title":"Piso en avenida de l\'Erampruny\xc3\xa0","subtitle":"Centre - Colomeres - Ramblas, Gav\xc3\xa0"}},{"propertyCode":"35148257","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRPCtYkDlgxw%2FJv%2FD%2FUHF%2FVr%2BJyVwbHOhNaW%2FpXz7hXRwenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=-1210008765","numPhotos":11,"floor":"2","price":550.0,"propertyType":"flat","operation":"rent","size":75.0,"exterior":false,"rooms":3,"bathrooms":2,"address":"calle de la Cucurulla, 9","province":"Barcelona","municipality":"Barcelona","district":"Ciutat Vella","country":"es","neighborhood":"El G\xc3\xb2tic","latitude":41.3843847,"longitude":2.174086,"showAddress":true,"url":"http://www.idealista.com/35148257","distance":"1990","hasVideo":false,"status":"good","newDevelopment":false,"hasLift":true,"priceByArea":7.0,"detailedType":{"typology":"flat"},"suggestedTexts":{"title":"Piso en calle de la Cucurulla, 9","subtitle":"El G\xc3\xb2tic, Barcelona"}},{"propertyCode":"35148167","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRFI3SKn470arAtWE%2BHNUNoGStI9fsVGn42PPGNVYXlD9enbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=834427565","externalReference":"12844","numPhotos":20,"floor":"bj","price":1300.0,"propertyType":"chalet","operation":"rent","size":175.0,"exterior":false,"rooms":3,"bathrooms":2,"address":"dels roures","province":"Barcelona","municipality":"Vacarisses","country":"es","latitude":41.5998536,"longitude":1.8986187,"showAddress":false,"url":"http://www.idealista.com/35148167","distance":"31605","hasVideo":false,"status":"good","newDevelopment":false,"parkingSpace":{"hasParkingSpace":true,"isParkingSpaceIncludedInPrice":true},"priceByArea":7.0,"detailedType":{"typology":"chalet","subTypology":"independantHouse"},"suggestedTexts":{"title":"Casa independiente en dels roures","subtitle":"Vacarisses"}},{"propertyCode":"35148156","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRCguzFdVm2a8zkIPlee5TGq0A%2BdshPRS%2BrpeABV8CY4EenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=-451992724","externalReference":"PV1599","numPhotos":1,"floor":"bj","price":600.0,"propertyType":"studio","operation":"rent","size":27.0,"exterior":true,"rooms":0,"bathrooms":1,"address":"Torrent Ballester","province":"Barcelona","municipality":"Viladecans","district":"Torrent Ballester","country":"es","latitude":41.3175644,"longitude":2.0073415,"showAddress":false,"url":"http://www.idealista.com/35148156","distance":"16607","hasVideo":false,"status":"good","newDevelopment":false,"hasLift":false,"priceByArea":22.0,"detailedType":{"typology":"flat","subTypology":"studio"},"suggestedTexts":{"title":"Estudio","subtitle":"Torrent Ballester, Viladecans"}},{"propertyCode":"35148090","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQREM%2BpLrzYtqb0ig66pWAjq8uIDjVGG5UsGNrkReAk2VKenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRY ...

# %%
#content.decode("UTF-8")
print type(content)
print type(content.decode("utf-8"))
print content.decode("utf-8")
# Out:
# <type 'str'>
# <type 'unicode'>
# {"elementList":[{"propertyCode":"35148292","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRBIt304N1zbEaVTYiMKa7peJb6h3pOitYjII8tYJyqXAenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=871973808","externalReference":"gava 650","numPhotos":6,"floor":"4","price":650.0,"propertyType":"flat","operation":"rent","size":66.0,"exterior":true,"rooms":3,"bathrooms":1,"address":"avenida de l'Eramprunyà","province":"Barcelona","municipality":"Gavà","district":"Centre - Colomeres - Ramblas","country":"es","latitude":41.3086987,"longitude":1.9935823,"showAddress":false,"url":"http://www.idealista.com/35148292","distance":"18113","hasVideo":false,"status":"good","newDevelopment":false,"hasLift":true,"priceByArea":10.0,"detailedType":{"typology":"flat"},"suggestedTexts":{"title":"Piso en avenida de l'Eramprunyà","subtitle":"Centre - Colomeres - Ramblas, Gavà"}},{"propertyCode":"35148257","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRPCtYkDlgxw%2FJv%2FD%2FUHF%2FVr%2BJyVwbHOhNaW%2FpXz7hXRwenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=-1210008765","numPhotos":11,"floor":"2","price":550.0,"propertyType":"flat","operation":"rent","size":75.0,"exterior":false,"rooms":3,"bathrooms":2,"address":"calle de la Cucurulla, 9","province":"Barcelona","municipality":"Barcelona","district":"Ciutat Vella","country":"es","neighborhood":"El Gòtic","latitude":41.3843847,"longitude":2.174086,"showAddress":true,"url":"http://www.idealista.com/35148257","distance":"1990","hasVideo":false,"status":"good","newDevelopment":false,"hasLift":true,"priceByArea":7.0,"detailedType":{"typology":"flat"},"suggestedTexts":{"title":"Piso en calle de la Cucurulla, 9","subtitle":"El Gòtic, Barcelona"}},{"propertyCode":"35148167","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRFI3SKn470arAtWE%2BHNUNoGStI9fsVGn42PPGNVYXlD9enbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=834427565","externalReference":"12844","numPhotos":20,"floor":"bj","price":1300.0,"propertyType":"chalet","operation":"rent","size":175.0,"exterior":false,"rooms":3,"bathrooms":2,"address":"dels roures","province":"Barcelona","municipality":"Vacarisses","country":"es","latitude":41.5998536,"longitude":1.8986187,"showAddress":false,"url":"http://www.idealista.com/35148167","distance":"31605","hasVideo":false,"status":"good","newDevelopment":false,"parkingSpace":{"hasParkingSpace":true,"isParkingSpaceIncludedInPrice":true},"priceByArea":7.0,"detailedType":{"typology":"chalet","subTypology":"independantHouse"},"suggestedTexts":{"title":"Casa independiente en dels roures","subtitle":"Vacarisses"}},{"propertyCode":"35148156","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQRCguzFdVm2a8zkIPlee5TGq0A%2BdshPRS%2BrpeABV8CY4EenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch=-451992724","externalReference":"PV1599","numPhotos":1,"floor":"bj","price":600.0,"propertyType":"studio","operation":"rent","size":27.0,"exterior":true,"rooms":0,"bathrooms":1,"address":"Torrent Ballester","province":"Barcelona","municipality":"Viladecans","district":"Torrent Ballester","country":"es","latitude":41.3175644,"longitude":2.0073415,"showAddress":false,"url":"http://www.idealista.com/35148156","distance":"16607","hasVideo":false,"status":"good","newDevelopment":false,"hasLift":false,"priceByArea":22.0,"detailedType":{"typology":"flat","subTypology":"studio"},"suggestedTexts":{"title":"Estudio","subtitle":"Torrent Ballester, Viladecans"}},{"propertyCode":"35148090","thumbnail":"https://img3.idealista.com/thumbs?wi=140&he=105&en=%2BtSLyO%2BcnvWFQ1vfQ1%2FQREM%2BpLrzYtqb0ig66pWAjq8uIDjVGG5UsGNrkReAk2VKenbPKfuOPIaCEFuXJKqGB5cU1VWesisrLJUHqccKZOukuYN5VRYLz1RLlDEtglEcKFetA5LMd2SHdJFqqai0nA%3D%3D&ch= ...

# %%
def from_json_to_csv(values):
    #with open('raw_update_rentdata.txt') as data_file:
    #    print(unidecode.unidecode(data_file.read())) 
    #    values = json.loads(unidecode.unidecode(data_file.read()))
        
    f = csv.writer(open("update_rentdata_test.csv", "a"))

    # Write CSV Header, If you dont need that, remove this line
    f.writerow(["propertyCode", "thumbnail", "numPhotos", "floor", "price", "propertyType", "operation", "size", "exterior", "rooms", "bathrooms", "address", "province", "municipality","district", "country", "neighborhood", "latitude", "longitude", "showAddress", "url", "distance","hasVideo", "newDevelopment", "tenantNumber", "tenantGender", "hasLift", "isSmokingAllowed","priceByArea"])
    
    values=values.decode("utf-8").encode("utf-8")
    for element in values["elementList"]:
        f.writerow([save_check(element, "propertyCode"), save_check(element, "thumbnail"), save_check(element, "numPhotos"), save_check(element, "floor"), save_check(element, "price"), save_check(element, "propertyType"), save_check(element, "operation"), save_check(element, "size"), save_check(element, "exterior"), save_check(element, "rooms"), save_check(element, "bathrooms"), save_check(element, "address"), save_check(element, "province"), save_check(element, "municipality"), save_check(element, "district"), save_check(element, "country"), save_check(element, "neighborhood"), save_check(element, "latitude"), save_check(element, "longitude"), save_check(element, "showAddress"), save_check(element, "url"), save_check(element, "distance"), save_check(element, "hasVideo"), save_check(element, "newDevelopment"), save_check(element, "tenantNumber"), save_check(element, "tenantGender"), save_check(element, "hasLift"), save_check(element, "isSmokingAllowed"), save_check(element, "priceByArea")])

# %%
f = csv.writer(open("update_rentdata_test.csv", "a"))
for element in content["elementList"]:
    #content["elementList"]
    f.writerow([save_check(element, "propertyCode"), save_check(element, "thumbnail").decode("utf-8", "replace"), save_check(element, "numPhotos"), save_check(element, "floor").decode("utf-8", "replace"), save_check(element, "price"), save_check(element, "propertyType").decode("utf-8", "replace"), save_check(element, "operation").decode("utf-8", "replace"), save_check(element, "size"), save_check(element, "exterior"), save_check(element, "rooms"), save_check(element, "bathrooms"), save_check(element, "province").decode("utf-8", "replace"), save_check(element, "municipality").decode("utf-8", "replace"), save_check(element, "district").decode("utf-8", "replace"), save_check(element, "country"), save_check(element, "neighborhood").decode("utf-8", "replace"), save_check(element, "latitude"), save_check(element, "longitude"), save_check(element, "showAddress"), save_check(element, "url").decode("utf-8", "replace"), save_check(element, "distance"), save_check(element, "hasVideo"), save_check(element, "newDevelopment"), save_check(element, "tenantNumber"), save_check(element, "tenantGender"), save_check(element, "hasLift"), save_check(element, "isSmokingAllowed"), save_check(element, "priceByArea")])
# Out:
# UnicodeEncodeErrorTraceback (most recent call last)
# <ipython-input-91-f3ec081f19c7> in <module>()
#       2 for element in content["elementList"]:
#       3     #content["elementList"]
# ----> 4     f.writerow([save_check(element, "propertyCode"), save_check(element, "thumbnail").decode("utf-8", "replace"), save_check(element, "numPhotos"), save_check(element, "floor").decode("utf-8", "replace"), save_check(element, "price"), save_check(element, "propertyType").decode("utf-8", "replace"), save_check(element, "operation").decode("utf-8", "replace"), save_check(element, "size"), save_check(element, "exterior"), save_check(element, "rooms"), save_check(element, "bathrooms"), save_check(element, "province").decode("utf-8", "replace"), save_check(element, "municipality").decode("utf-8", "replace"), save_check(element, "district").decode("utf-8", "replace"), save_check(element, "country"), save_check(element, "neighborhood").decode("utf-8", "replace"), save_check(element, "latitude"), save_check(element, "longitude"), save_check(element, "showAddress"), save_check(element, "url").decode("utf-8", "replace"), save_check(element, "distance"), save_check(element, "hasVideo"), save_check(element, "newDevelopment"), save_check(element, "tenantNumber"), save_check(element, "tenantGender"), save_check(element, "hasLift"), save_check(element, "isSmokingAllowed"), save_check(element, "priceByArea")])
#
# C:\Program Files\Anaconda2\lib\encodings\utf_8.pyc in decode(input, errors)
#      14
#      15 def decode(input, errors='strict'):
# ---> 16     return codecs.utf_8_decode(input, errors, True)
#      17
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xe0' in position 5: ordinal not in range(128)

# %%
def from_csv_to_db(filename):
    mydb = MySQLdb.connect(host='192.185.92.181',
        user='rentcoac_adsteam',
        passwd='LlB7Rq1CMP]z',
        db='rentcoac_ads')
    cursor = mydb.cursor()

    csv_data = csv.reader(file(filename + '.csv'))
    for row in csv_data:

        cursor.execute('INSERT INTO testcsv(names, \
              classes, mark )' \
              'VALUES("%s", "%s", "%s")', 
              row)
    #close the connection to the database.
    mydb.commit()
    cursor.close()

# %%
token = get_oauth_token()
print(token)
content = search_api(token, 1)
#numPage = content["totalPages"]
"""
from_json_to_csv(content)
for page in range(2,numPage):
    content = search_api(token, page)
    print(content)
    from_json_to_csv(content)

#mapping_db(search_api(""))
#print(get_oauth_token())
"""
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE0NzkyMzYxMzYsInNjb3BlIjpbInJlYWQiXSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMTgwZWI2NDgtMWI0Yy00NjMyLWJiYzAtNTk2ZGZjNmJjZjg3IiwiY2xpZW50X2lkIjoiZmN2OWgybXAxcmRsZnJiZWl1aDV1bXo1b2Vya2pwaXkifQ.wGsr3evV38qPsgymPsyP8iXhzvURSI36qPEerVn5lkY
# '\nfrom_json_to_csv(content)\nfor page in range(2,numPage):\n    content = search_api(token, page)\n    print(content)\n    from_json_to_csv(content)\n\n#mapping_db(search_api(""))\n#print(get_oauth_token())\n'

# %%
type(content)
# Out:
# dict

# %%
def get_keys(dl, keys_list):
    if isinstance(dl, dict):
        keys_list += dl.keys()
        map(lambda x: get_keys(x, keys_list), dl.values())
    elif isinstance(dl, list):
        map(lambda x: get_keys(x, keys_list), dl)

# %%
keys_list=[]
output=[]
keys_list=[u"status"]
output=[u"status"]
get_keys(content["elementList"],keys_list)
for x in keys_list:
    if x not in output:
        output.append(x)
print output
# Out:
# [u'status', u'bathrooms', u'hasLift', u'propertyType', u'municipality', u'newDevelopment', u'rooms', u'exterior', u'neighborhood', u'operation', u'detailedType', u'size', u'suggestedTexts', u'district', u'floor', u'numPhotos', u'hasVideo', u'latitude', u'propertyCode', u'thumbnail', u'province', u'price', u'address', u'externalReference', u'distance', u'url', u'country', u'longitude', u'priceByArea', u'showAddress', u'typology', u'subtitle', u'title', u'parkingSpace', u'subTypology', u'hasParkingSpace', u'isParkingSpaceIncludedInPrice']

# %%
b=["propertyCode", "thumbnail", "numPhotos", "floor", "price", "propertyType", "operation", "size", "exterior", "rooms", "bathrooms", "address", "province", "municipality","district", "country", "neighborhood", "latitude", "longitude", "showAddress", "url", "distance","hasVideo", "newDevelopment", "tenantNumber", "tenantGender", "hasLift", "isSmokingAllowed","priceByArea"]
len(b)
# Out:
# 29

# %%
dct=content["elementList"][0]
keys = set()
for subdct in dct.values():
    keys |= set(subdct)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-161-c1fc1671e53b> in <module>()
#       2 keys = set()
#       3 for subdct in dct.values():
# ----> 4     keys |= set(subdct)
#
# TypeError: 'int' object is not iterable
